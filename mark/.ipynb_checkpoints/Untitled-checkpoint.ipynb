# %%
# !pip install --upgrade numpy scikit-learn
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.0.2)
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.0.2)
# Collecting scikit-learn
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/1c/ce/af9d99533b24c55ff4e18d9b7b4d9919bbc6cd8f22fe7a7be01519a347d5/scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
#   WARNING: Connection timed out while downloading.
#   WARNING: Attempting to resume incomplete download (0 bytes/11 kB, attempt 1)
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: scipy>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
# Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl (8.7 MB)
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/8.7 MB 52.7 kB/s eta 0:02:20m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (1.3 MB/8.7 MB, attempt 1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/1c/ce/af9d99533b24c55ff4e18d9b7b4d9919bbc6cd8f22fe7a7be01519a347d5/scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl
# Resuming download scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl (1.3 MB/8.7 MB)
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/8.7 MB ? eta -:--:--0m
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (1.3 MB/8.7 MB, attempt 2)
# Resuming download scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl (1.3 MB/8.7 MB)
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/8.7 MB ? eta -:--:--0m

# %%
import pandas as pd

# %%
df = pd.read_csv('deepface_predictions-5.csv')

# Split filename into parts
parts = df["filename"].str.split("_", expand=True)

# Extract numeric codes
df["face_id"] = parts[1]
df["race_code"] = parts[2].astype(int)
df["age_code"] = parts[3].astype(int)
df["gender_code"] = parts[4].astype(int)

# %%
df.head(5)
# Out:
#                       filename  age gender            race face_id  race_code  \
# 0  fairface_4394_0_7_0_val.jpg   32    Man           asian    4394          0
# 1   fairface_707_5_3_0_val.jpg   26    Man  middle eastern     707          5
# 2  fairface_2303_2_5_1_val.jpg   33  Woman           black    2303          2
# 3  fairface_8241_1_6_1_val.jpg   39    Man          indian    8241          1
# 4  fairface_2599_0_3_0_val.jpg   30    Man           asian    2599          0
#
#    age_code  gender_code
# 0         7            0
# 1         3            0
# 2         5            1
# 3         6            1
# 4         3            0

# %%
import pandas as pd

# Example dataframe
# df has: filename, age, gender, race, age_code, gender_code, race_code

# Mappings
race_map = {
    0: "asian", 1: "indian", 2: "black", 3: "white",
    4: "middle eastern", 5: "latino hispanic"
}
age_map = {
    0: "0-2", 1: "3-9", 2: "10-19", 3: "20-29",
    4: "30-39", 5: "40-49", 6: "50-59", 7: "60-69", 8: "+70"
}
gender_map = {0: "Man", 1: "Woman"}

# Inverse mappings
race_inv = {v.lower(): k for k, v in race_map.items()}
gender_inv = {v.lower(): k for k, v in gender_map.items()}

# Function: convert raw age int → encoded int
def encode_age(age: int) -> int:
    if 0 <= age <= 2: return 0
    elif 3 <= age <= 9: return 1
    elif 10 <= age <= 19: return 2
    elif 20 <= age <= 29: return 3
    elif 30 <= age <= 39: return 4
    elif 40 <= age <= 49: return 5
    elif 50 <= age <= 59: return 6
    elif 60 <= age <= 69: return 7
    else: return 8   # 70+

# Encode predictions
df["pred_gender_code"] = df["gender"].str.lower().map(gender_inv)
df["pred_race_code"]   = df["race"].str.lower().map(race_inv)
df["pred_age_code"]    = df["age"].apply(encode_age)

df.head()
# Out:
#                       filename  age gender            race face_id  race_code  \
# 0  fairface_4394_0_7_0_val.jpg   32    Man           asian    4394          0
# 1   fairface_707_5_3_0_val.jpg   26    Man  middle eastern     707          5
# 2  fairface_2303_2_5_1_val.jpg   33  Woman           black    2303          2
# 3  fairface_8241_1_6_1_val.jpg   39    Man          indian    8241          1
# 4  fairface_2599_0_3_0_val.jpg   30    Man           asian    2599          0
#
#    age_code  gender_code  pred_gender_code  pred_race_code  pred_age_code
# 0         7            0                 0               0              4
# 1         3            0                 0               4              3
# 2         5            1                 1               2              4
# 3         6            1                 0               1              4
# 4         3            0                 0               0              4

# %%
df.loc[df['race_code'] == 6, 'race_code'] = 0

# %%
df.head()
# Out:
#                       filename  age gender            race face_id  race_code  \
# 0  fairface_4394_0_7_0_val.jpg   32    Man           asian    4394          0
# 1   fairface_707_5_3_0_val.jpg   26    Man  middle eastern     707          5
# 2  fairface_2303_2_5_1_val.jpg   33  Woman           black    2303          2
# 3  fairface_8241_1_6_1_val.jpg   39    Man          indian    8241          1
# 4  fairface_2599_0_3_0_val.jpg   30    Man           asian    2599          0
#
#    age_code  gender_code  pred_gender_code  pred_race_code  pred_age_code
# 0         7            0                 0               0              4
# 1         3            0                 0               4              3
# 2         5            1                 1               2              4
# 3         6            1                 0               1              4
# 4         3            0                 0               0              4

# %%
from sklearn.metrics import accuracy_score, classification_report

# --- Accuracy scores ---
gender_acc = accuracy_score(df["gender_code"], df["pred_gender_code"])
race_acc   = accuracy_score(df["race_code"], df["pred_race_code"])
age_acc    = accuracy_score(df["age_code"], df["pred_age_code"])

print(f"Gender Accuracy: {gender_acc:.3f}")
print(f"Race Accuracy:   {race_acc:.3f}")
print(f"Age Accuracy:    {age_acc:.3f}")

# --- Detailed reports ---
print("\n--- Gender Report ---")
print(classification_report(
    df["gender_code"], df["pred_gender_code"],
    target_names=list(gender_map.values())
))

print("\n--- Race Report ---")
print(classification_report(
    df["race_code"], df["pred_race_code"],
    target_names=list(race_map.values())
))

print("\n--- Age Report ---")
print(classification_report(
    df["age_code"], df["pred_age_code"],
    target_names=list(age_map.values())
))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from sklearn.metrics import accuracy_score, classification_report
#       3 # --- Accuracy scores ---
#       4 gender_acc = accuracy_score(df["gender_code"], df["pred_gender_code"])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/__init__.py:82
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)
#     128     "show_versions",
#     129 ]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:17
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#      20     _safe_tags,
#      21 )
#      22 from .utils.validation import check_X_y
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/__init__.py:23
#      20 import numpy as np
#      21 from scipy.sparse import issparse
# ---> 23 from .murmurhash import murmurhash3_32
#      24 from .class_weight import compute_class_weight, compute_sample_weight
#      25 from . import _joblib
#
# File sklearn/utils/murmurhash.pyx:1, in init sklearn.utils.murmurhash()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
